# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('placement.csv')
data
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
print(data['cgpa'].corr(data['placement_exam_marks']))
# Out:
# -0.02737092008273521

# %%
plt.scatter(data['cgpa'], data['placement_exam_marks'])
#plt.plot(data['cgpa'], data['placement_exam_marks'], color='red')

# %%
data = pd.read_csv('insurance.csv')
data
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000

# %%
plt.scatter(data['Age'], data['Premium'])

# %%
print(data['Age'].corr(data['Premium']))
# Out:
# 0.9843315554722871

# %%
x = data[['Age']]
y = data['Premium']

model = LinearRegression()
model.fit(x, y)
m = model.coef_[0]
b = model.intercept_
print("m : ", model.coef_[0])
print("b : ", model.intercept_)

from sklearn.metrics import r2_score

y_test = data['Premium']
x_val = data['Age']
y_pred = model.predict(x)
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# m :  1172.9452054794515
# b :  -10114.726027397246
# 0.9689086110984921

# %%
plt.scatter(data['Age'], data['Premium'])
x_line = np.linspace(data['Age'].min(), data['Age'].max(), 100)
plt.plot(x_line, m * x_line + b, color='red', label = f"y = {m:.2f}x + {b:.2f}")
plt.xlabel('Age')
plt.ylabel('Premium')
plt.legend()
plt.title(f'Linear Regression: Age vs Premium (R² = {r2:.2f})')
# Out:
# Text(0.5, 1.0, 'Linear Regression: Age vs Premium (R² = 0.97)')
